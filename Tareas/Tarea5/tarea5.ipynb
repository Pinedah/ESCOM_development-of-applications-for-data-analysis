# %%
import pandas as pd

# %%
archivo = 'dataset.csv'
ds = pd.read_csv(archivo)

# %%
ds.head()
# Out:
#    User ID   Age  Gender    Country  Purchase Amount Purchase Date  \
# 0        1  56.0  Female        USA           331.79    2021-11-21
# 1        2  69.0    Male  Australia           335.72    2022-03-05
# 2        3  46.0     NaN    Germany           493.18           NaN
# 3        4  32.0    Male    Germany            80.97    2023-06-08
# 4        5  60.0  Female         UK            21.75           NaN
#
#   Product Category
# 0           Sports
# 1   Home & Kitchen
# 2            Books
# 3           Sports
# 4           Beauty

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User ID           15000 non-null  int64
#  1   Age               13500 non-null  float64
#  2   Gender            14250 non-null  object
#  3   Country           13800 non-null  object
#  4   Purchase Amount   13200 non-null  float64
#  5   Purchase Date     13950 non-null  object
#  6   Product Category  14100 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 820.4+ KB

# %%
ds.info(), ds.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User ID           15000 non-null  int64
#  1   Age               13500 non-null  float64
#  2   Gender            14250 non-null  object
#  3   Country           13800 non-null  object
#  4   Purchase Amount   13200 non-null  float64
#  5   Purchase Date     13950 non-null  object
#  6   Product Category  14100 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 820.4+ KB
# (None,
#  User ID                0
#  Age                 1500
#  Gender               750
#  Country             1200
#  Purchase Amount     1800
#  Purchase Date       1050
#  Product Category     900
#  dtype: int64)

# %%
ds[['User ID', 'Age']]
# Out:
#        User ID   Age
# 0            1  56.0
# 1            2  69.0
# 2            3  46.0
# 3            4  32.0
# 4            5  60.0
# ...        ...   ...
# 14995    14996  21.0
# 14996    14997  53.0
# 14997    14998  65.0
# 14998    14999  34.0
# 14999    15000   NaN
#
# [15000 rows x 2 columns]

# %%
ds.Country.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ds.Country.plot()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
# ...

# %%
# Supongamos que 'ds' es tu DataFrame y 'Clase' es la columna de clases
class_counts = ds['Gender'].value_counts()

print("Conteo de cada clase:")
print(class_counts)

# Opcional: calcular la proporción de cada clase
class_proportion = ds['Gender'].value_counts(normalize=True)
print("\nProporción de cada clase:")
print(class_proportion)
# Out:
# Conteo de cada clase:
# Gender
# Female    4818
# Other     4742
# Male      4690
# Name: count, dtype: int64
#
# Proporción de cada clase:
# Gender
# Female    0.338105
# Other     0.332772
# Male      0.329123
# Name: proportion, dtype: float64

# %%
list(ds.head(0))
# Out:
# ['User ID',
#  'Age',
#  'Gender',
#  'Country',
#  'Purchase Amount',
#  'Purchase Date',
#  'Product Category']

# %%
for head in list(ds.head(0)):
    class_counts = ds[head].value_counts()

    print("Conteo de cada clase:")
    print(class_counts)

    # Opcional: calcular la proporción de cada clase
    class_proportion = ds[head].value_counts(normalize=True)
    print("\nProporción de cada clase:")
    print(class_proportion)
# Out:
# Conteo de cada clase:
# User ID
# 1        1
# 10005    1
# 9993     1
# 9994     1
# 9995     1
#         ..
# 5005     1
# 5006     1
# 5007     1
# 5008     1
# 15000    1
# Name: count, Length: 15000, dtype: int64
#
# Proporción de cada clase:
# User ID
# 1        0.000067
# 10005    0.000067
# 9993     0.000067
# 9994     0.000067
# 9995     0.000067
#            ...
# 5005     0.000067
# 5006     0.000067
# 5007     0.000067
# 5008     0.000067
# 15000    0.000067
# Name: proportion, Length: 15000, dtype: float64
# Conteo de cada clase:
# Age
# 43.0    301
# 30.0    292
# 40.0    287
# 34.0    286
# 46.0    284
# 62.0    278
# 64.0    277
# 45.0    276
# 59.0    274
# 38.0    273
# 29.0    271
# 33.0    270
# 50.0    270
# 20.0    269
# 66.0    269
# 35.0    269
# 61.0    267
# 19.0    266
# 36.0    266
# 42.0    266
# 54.0    266
# 41.0    265
# 25.0    263
# 65.0    262
# 27.0    261
# 52.0    261
# 32.0    261
# 21.0    261
# 23.0    260
# 39.0    259
# 56.0    258
# ...

# %%
class_counts = ds['Gender'].value_counts()

print("Conteo de cada clase:")
print(class_counts)

# Opcional: calcular la proporción de cada clase
class_proportion = ds['Gender'].value_counts(normalize=True)
print("\nProporción de cada clase:")
print(class_proportion)

class_counts
# Out:
# Conteo de cada clase:
# Gender
# Female    4818
# Other     4742
# Male      4690
# Name: count, dtype: int64
#
# Proporción de cada clase:
# Gender
# Female    0.338105
# Other     0.332772
# Male      0.329123
# Name: proportion, dtype: float64
# Gender
# Female    4818
# Other     4742
# Male      4690
# Name: count, dtype: int64

# %%
type(class_counts)
class_counts.Female / class_counts.Male, class_counts.argmax
# Out:
# (1.0272921108742004,
#  <bound method IndexOpsMixin.argmax of Gender
#  Female    4818
#  Other     4742
#  Male      4690
#  Name: count, dtype: int64>)

# %%
for c in class_counts:
    print(c)

max(class_counts) / min(class_counts)
# Out:
# 4818
# 4742
# 4690
# 1.0272921108742004
